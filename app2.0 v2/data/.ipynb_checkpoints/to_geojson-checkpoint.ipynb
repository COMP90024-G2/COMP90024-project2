# %%
import json

sa3_code = ['20601', '20602', '20603', '20604', '20605', '20607', '20701', '20702', '20606', '20703', '20801', '20902', '20903', '20904',
           '21001', '21002', '20802', '20803', '20804', '20901', '21003', '21004', '21005', '21101', '21102', '21103', '21104', '21105',
           '21201', '21202', '21203', '21204', '21205', '21301', '21302', '21303', '21304', '21305', '21401', '21402']

if __name__ == "__main__":
    with open("language_count.json") as f:
        data = json.load(f)
        for code in sa3_code:
            for region in data[code]:
                print(region)
                with open('processed.geojson', 'w') as fp:
                    json.dump(region, fp)
                


#         result = {"type": "FeatureCollection", "features": []}
#         for key, value in data:
#             feature = {"type": "Feature", "geometry": {}, "properties": {}}

#             feature["geometry"] = {"type": "Polygen",
#                                    "coordinates": tweet["geo"]}
#             feature["properties"]["polarity"] = tweet["polarity"]
#             feature["properties"]["subjectivity"] = tweet["subjectivity"]

#             result["features"].append(feature)

#         with open('processed.geojson', 'w') as fp:
#             json.dump(result, fp)
print(len(data))
# Out:
# sa3name
# sa3code
# shape
# coordinates
# tweet_count
# language
# general_emotion
# positive_tweets_percent
# neutral_tweets_percent
# negative_tweets_percent
# employment_attitude
# healthcare_attitude
# aurin_language
# aurin_income
# aurin_health
# sa3name
# sa3code
# shape
# coordinates
# tweet_count
# language
# general_emotion
# positive_tweets_percent
# neutral_tweets_percent
# negative_tweets_percent
# employment_attitude
# healthcare_attitude
# aurin_language
# aurin_income
# aurin_health
# sa3name
# sa3code
# shape
# coordinates
# tweet_count
# language
# general_emotion
# positive_tweets_percent
# neutral_tweets_percent
# negative_tweets_percent
# employment_attitude
# healthcare_attitude
# aurin_language
# aurin_income
# aurin_health
# sa3name
# sa3code
# shape
# coordinates
# tweet_count
# language
# general_emotion
# positive_tweets_percent
# neutral_tweets_percent
# negative_tweets_percent
# employment_attitude
# healthcare_attitude
# aurin_language
# aurin_income
# ...

# %%
data
# Out:
# {'20601': {'sa3name': 'Brunswick - Coburg',
#   'sa3code': '20601',
#   'shape': 'MultiPolygon',
#   'coordinates': [[[[144.974690994, -37.779792213],
#      [144.97349759, -37.7796473029999],
#      [144.973330894, -37.7796271559999],
#      [144.972764962, -37.779558762],
#      [144.971282405, -37.7793800699999],
#      [144.970525796, -37.779289106],
#      [144.969003016, -37.7791087489999],
#      [144.968096758, -37.779238989],
#      [144.967641968, -37.779318706],
#      [144.967712668, -37.778948558],
#      [144.967216816, -37.778888692],
#      [144.965986547, -37.778740285],
#      [144.965194205, -37.778644621],
#      [144.963940905, -37.778493421],
#      [144.963335881, -37.7784204009999],
#      [144.962482145, -37.778317393],
#      [144.961631586, -37.778214755],
#      [144.961472884, -37.7781956069999],
#      [144.960233745, -37.7780442219999],
#      [144.959901486, -37.77800589],
#      [144.959260948, -37.7779286159999],
# ...
